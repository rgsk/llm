# %% [markdown]
# lora joint model train with grad_clip=1e9, to test if adamw optimizer handles gradient spikes

# %% [markdown]
# adamw configure optimizer

# %% [markdown]
# add resume training from sft

# %% [markdown]
# log gnorm in main.py to wandb (at every step)

# %% [markdown]
# do sinusoidal embeddings after PE, and ROPE
