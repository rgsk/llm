# %% [markdown]
# check if smaller r, fits reversal task

# %% [markdown]
# lora_adapter

# %% [markdown]
# And gnorm spiked to 31.7 and 16.8 mid-transition, so grad_clip=2.0 was doing real work here for the first time; the frozen base tames gradients on smooth tasks, not during a capability snap

# %% [markdown]
# ### combining lora adapters
#
#  W·x + s·B₁A₁x + s·B₂A₂x.
#
#  either just load adapter 2 on top, or train adapter 2 fresh on the merged model. The trained version is strictly better behaved (adapter 2 learns in the presence of adapter 1's changes) but is no longer symmetric: you chose an order, and adapter 2 only works over that merged base.
#
# Joint training — one adapter, mixed instruct+reverse data.
