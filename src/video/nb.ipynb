# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from module import Module
from parameter import Parameter
import torch
from torch import nn
from module_list import ModuleList

# %%
class MyLin(Module):
    def __init__(self, i, o):
        self.w = Parameter(torch.randn(o, i))
        self.b = Parameter(torch.zeros(o))

    def forward(self, x):
        return x @ self.w.T + self.b
        
class Net(Module):
    def __init__(self):
        self.layers = ModuleList([MyLin(4, 8), MyLin(8, 8)])
        self.head = MyLin(8, 2)

    def forward(self, x):
        for l in self.layers:
            x = l(x)
        return self.head(x)

net = Net()
[n for n, _ in net.named_parameters()]
# Out:
# ['layers.0.w', 'layers.0.b', 'layers.1.w', 'layers.1.b', 'head.w', 'head.b']

# %%
print(net.__dict__.keys())
print(net.__dict__['layers'].__dict__.keys())
# Out:
# dict_keys(['layers', 'head'])
# dict_keys(['_n', '0', '1'])

# %%
getattr(net.layers, "0")     # <MyLin object>   (net.layers.0 isn't valid syntax, but the attribute is there)
