# %%
# %load_ext autoreload
# %autoreload 2

# %%
from module import Module
from parameter import Parameter
import torch
from torch import nn
from module_list import ModuleList

# %%
class MyLin(Module):
    def __init__(self, i, o):
        self.w = Parameter(torch.randn(o, i))
        self.b = Parameter(torch.zeros(o))

    def forward(self, x):
        return x @ self.w.T + self.b
        
class Net(Module):
    def __init__(self):
        self.layers = ModuleList([MyLin(4, 8), MyLin(8, 8)])
        self.head = MyLin(8, 2)

    def forward(self, x):
        for l in self.layers:
            x = l(x)
        return self.head(x)

net = Net()
[(n, v) for n, v in net.named_parameters()]
# Out:
# [('layers.0.w',
#   Parameter([[-0.8192,  1.1328, -1.5082,  0.2423],
#              [ 1.1797,  0.4416,  1.1325, -0.5712],
#              [ 2.1473, -0.6746, -0.5989,  1.2434],
#              [ 0.8367, -0.3501, -1.7324, -0.4388],
#              [-0.1669,  0.1184,  0.2151, -0.1646],
#              [ 1.2292, -0.9966, -0.3785,  0.2147],
#              [ 1.1141, -1.4626,  1.3662, -1.6546],
#              [ 0.7829,  0.4365, -1.9299,  1.1325]], requires_grad=True)),
#  ('layers.0.b',
#   Parameter([0., 0., 0., 0., 0., 0., 0., 0.], requires_grad=True)),
#  ('layers.1.w',
#   Parameter([[ 0.1264,  0.4427,  0.0063,  1.3889, -0.5369, -2.7374,  0.5608,
#               -0.5105],
#              [-0.4699, -1.6753,  0.6670, -0.1792,  0.2745, -0.1045, -0.7982,
#               -0.9128],
#              [-0.2107, -0.2067,  0.2298,  2.4640,  1.8989,  0.7912, -0.0786,
#                0.5889],
#              [ 0.0557, -0.8788, -0.9920,  0.9247, -0.3273,  0.1141, -0.2821,
#               -0.1247],
#              [-0.0467, -1.6124, -2.3872,  0.5708, -1.3103, -2.3604, -1.2765,
#               -0.0871],
#              [ 1.1772, -0.2780,  0.1568, -0.0801, -0.8411, -0.0096,  1.2523,
#               -0.0562],
#              [-0.3390, -0.3930, -0.7086, -1.6383, -1.0582, -0.5691, -0.8243,
#               -0.0328],
#              [-1.4523, -0.0340, -0.7477, -0.2336,  1.3138,  0.0276, -1.4793,
#               -1.2943]], requires_grad=True)),
#  ('layers.1.b',
#   Parameter([0., 0., 0., 0., 0., 0., 0., 0.], requires_grad=True)),
#  ('head.w',
#   Parameter([[ 0.2745,  0.6851,  1.3541, -0.1198, -1.1945,  0.2147, -0.5902,
#                0.0798],
#              [-0.0460,  0.5553, -0.7263, -1.4660,  0.0107, -0.8324, -0.6907,
#               -1.3967]], requires_grad=True)),
#  ('head.b', Parameter([0., 0.], requires_grad=True))]

# %%
0.05
# Out:
# hi

# %%
1e-2
# Out:
# 0.01
